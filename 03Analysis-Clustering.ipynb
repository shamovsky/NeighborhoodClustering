# %% [markdown]
# # Beginning of Analysis-Grouping

# %%
import numpy as np 
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json 
from geopy.geocoders import Nominatim 
import requests 
from pandas.io.json import json_normalize 
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium 
from bs4 import BeautifulSoup
import urllib3
tst=pd.read_csv('postcodes')
dft=pd.read_csv('dft')
toronto_grouped=pd.read_csv('torgroup')
neighborhoods_venues_sorted=pd.read_csv('venuessorted')    

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Kmeans clustering

# %%
kclusters =9
toronto_grouped_clustering = toronto_grouped.drop('Postcode', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)
kmeans.labels_[0:10]
# Out:
# array([3, 8, 6, 2, 3, 6, 6, 3, 2, 3], dtype=int32)

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
toronto_merged = dft
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Postcode'), on='Postcode')
toronto_merged.head()
# Out:
#   Postcode      Borough                        Neighbourhoods   Latitude  \
# 0      M1B  Scarborough                         Rouge,Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2      M1E  Scarborough       Guildwood,Morningside,West Hill  43.763573
# 3      M1G  Scarborough                                Woburn  43.770992
# 4      M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.194353             3.0  Fast Food Restaurant           Coffee Shop
# 1 -79.160497             8.0        Breakfast Spot          Burger Joint
# 2 -79.188711             6.0           Pizza Place  Fast Food Restaurant
# 3 -79.216917             2.0                  Park           Coffee Shop
# 4 -79.239476             3.0                Bakery           Coffee Shop
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# ...

# %%
toronto_merged[['Cluster Labels']]=toronto_merged[['Cluster Labels']].fillna(0,downcast='infer')
#np.nan_to_num(toronto_merged['Cluster Labels']).astype(int)
toronto_merged
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %% [markdown]
# # Creating new map of clusters with folium

# %%
latitude=43.6532
longitude=-79.3832
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Postcode'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## We see that cluster 0 has a trend of coffee shop, and cafe in the top three values

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 16       Scarborough               0                   NaN
# 40         East York               0           Coffee Shop
# 43      East Toronto               0           Coffee Shop
# 44   Central Toronto               0           College Gym
# 51  Downtown Toronto               0                  Park
# 55  Downtown Toronto               0           Coffee Shop
# 56  Downtown Toronto               0           Coffee Shop
# 58  Downtown Toronto               0                  Café
# 59  Downtown Toronto               0           Coffee Shop
# 60  Downtown Toronto               0           Coffee Shop
# 61  Downtown Toronto               0           Coffee Shop
# 65   Central Toronto               0                  Café
# 66  Downtown Toronto               0                  Café
# 67  Downtown Toronto               0                  Café
# 68  Downtown Toronto               0           Coffee Shop
# ...

# %% [markdown]
# # In cluster 2, we see a trend of park and pizza appearing often

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#         Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 3   Scarborough               2                  Park           Coffee Shop
# 8   Scarborough               2           Pizza Place                 Beach
# 31   North York               2                  Park           Coffee Shop
# 91    Etobicoke               2                  Park    Italian Restaurant
# 94    Etobicoke               2                  Park                 Hotel
# 96   North York               2                Bakery                  Bank
#
#    3rd Most Common Venue        4th Most Common Venue 5th Most Common Venue  \
# 3     Chinese Restaurant            Electronics Store  Fast Food Restaurant
# 8   Fast Food Restaurant                   Sports Bar          Burger Joint
# 31           Pizza Place        Vietnamese Restaurant         Grocery Store
# 91         Shopping Mall  Eastern European Restaurant        Ice Cream Shop
# ...

# %% [markdown]
# # Cluster 3 shows a trend of Coffee Shops

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels      1st Most Common Venue  \
# 0        Scarborough               3       Fast Food Restaurant
# 4        Scarborough               3                     Bakery
# 7        Scarborough               3                   Bus Line
# 9        Scarborough               3                       Park
# 10       Scarborough               3                   Pharmacy
# 11       Scarborough               3  Middle Eastern Restaurant
# 12       Scarborough               3         Chinese Restaurant
# 18        North York               3             Clothing Store
# 21        North York               3          Korean Restaurant
# 22        North York               3                Coffee Shop
# 23        North York               3                Coffee Shop
# 26        North York               3        Japanese Restaurant
# 27        North York               3                Coffee Shop
# 30        North York               3                Coffee Shop
# ...

# %% [markdown]
# # Cluster 4 has pharmacy more often than others

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#          Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 14   Scarborough               4    Chinese Restaurant          Noodle House
# 17    North York               4              Pharmacy           Coffee Shop
# 19    North York               4         Grocery Store   Japanese Restaurant
# 24    North York               4              Pharmacy                Bakery
# 25    North York               4                  Park     Convenience Store
# 74          York               4    Mexican Restaurant              Pharmacy
# 89     Etobicoke               4              Pharmacy        Discount Store
# 93  Queen's Park               4              Pharmacy     Convenience Store
# 97    North York               4                Bakery          Intersection
#
#           3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 14                         Park           Pizza Place  Caribbean Restaurant
# ...
